# %% [markdown]
# # LSTM support
#
# The following notebook contains a walkthrough of the support for the LSTM module
#
# The notebook is organized in the following sections:
# 1. Icefabric API support
# 2. Icefabric CLI support

# %%
# Running imports
import json
import os
import threading
import zipfile
from pathlib import Path

import httpx

# Changes the current working dir to be the project root
current_working_dir = Path.cwd()
os.chdir(Path.cwd() / "../../")
print(
    f"Changed current working dir from {current_working_dir} to: {Path.cwd()}. This must run at the project root"
)
# Out:
# Changed current working dir from /home/daniel.cumpton/icefabric/examples/initial_parameters to: /home/daniel.cumpton/icefabric. This must run at the project root

# %%
# Starting the API locally
def run_api():
    """Starts the icefabric API locally"""
    # !python -m app.main --catalog sql


threading.Thread(target=run_api).start()
# Out:
# INFO:     Will watch for changes in these directories: ['/home/daniel.cumpton/icefabric']
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [3772608] using WatchFiles
# INFO:     Started server process [3772671]
# INFO:     Waiting for application startup.
# Loading existing network graph from disk for: conus_hf
# Loading existing network graph from disk for: ak_hf
# Loading existing network graph from disk for: gl_hf
# Loading existing network graph from disk for: hi_hf
# Loading existing network graph from disk for: prvi_hf
# INFO:     Application startup complete.
# Starting subset for gages-01010000
# Found origin flowpath: wb-4581
# Tracking 170 total upstream segments
# Subsetting network layer
# Subsetting flowpaths layer
# Subsetting nexus layer
# Subsetting divides layer
# Subsetting divide-attributes layer
# INFO:     127.0.0.1:59456 - "GET /v1/modules/lstm/?identifier=01010000&domain=conus_hf&use_schaake=false HTTP/1.1" 200 OK

# %% [markdown]
# This will start the API on localhost:8000. This can be visited at: http://localhost:8000/docs
#
# ![Icefabric API](../../docs/img/icefabric_api.png)

# %% [markdown]
# To test the SFT endpoint, we can use an example API call. This will return all config entries in JSON form. Each item in the output is the BMI Config contents for a specific catchment upstream of USGS 01010000

# %%
# Make the request
response = httpx.get(
    "http://0.0.0.0:8000/v1/modules/lstm/",
    params={
        "identifier": "01010000",  # the Gauge ID we're testing
        "domain": "conus_hf",  # The CONUS domain
        "use_schaake": "false",  # Specifying we're not using Schaake for the ice fraction setting
    },
    timeout=60.0,  # GLUE API requests can be slow depending on the network speed. Adding a 30s timeout to ensure requests go through
)

print(f"Status code: {response.status_code}")
print(json.dumps(response.json(), indent=2))
# Out:
# Status code: 200
# [
#   {
#     "catchment": "cat-4564",
#     "area_sqkm": 65.10285020700276,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 392.67774687853324,
#     "inital_state": "zero",
#     "lat": -70.13892643795896,
#     "lon": 46.398022468189986,
#     "slope_mean": 38.919279112997955,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4568",
#     "area_sqkm": 7.097400207001865,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 366.7248617614768,
#     "inital_state": "zero",
#     "lat": -70.00487459822983,
#     "lon": 46.507973117315515,
#     "slope_mean": 43.05075248625828,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4575",
#     "area_sqkm": 26.379449856000228,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 353.3614140779505,
#     "inital_state": "zero",
#     "lat": -69.88320459514527,
#     "lon": 46.53046394628151,
#     "slope_mean": 57.5448016917151,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4581",
#     "area_sqkm": 4.796549945998919,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 319.32090844082353,
#     "inital_state": "zero",
#     "lat": -69.70866272622459,
#     "lon": 46.69459282971206,
#     "slope_mean": 61.72205058816875,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4758",
#     "area_sqkm": 5.224050251999784,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean":

#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4849",
#     "area_sqkm": 28.555199703006977,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 501.61254124348113,
#     "inital_state": "zero",
#     "lat": -70.16675558245782,
#     "lon": 46.15476003582794,
#     "slope_mean": 74.81587801211494,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4855",
#     "area_sqkm": 7.730550301498339,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 493.89646775730864,
#     "inital_state": "zero",
#     "lat": -70.14161108998132,
#     "lon": 46.1838382193304,
#     "slope_mean": 68.50089512112798,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4854",
#     "area_sqkm": 28.085849113493193,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 479.03384169782913,
#     "inital_state": "zero",
#     "lat": -70.21757815460532,
#     "lon": 46.17824431173699,
#     "slope_mean": 66.18460172291098,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4856",
#     "area_sqkm": 9.625049901002031,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 492.9996024919786,
#     "inital_state": "zero",
#     "lat": -70.13971419125663,
#     "lon": 46.203965060016515,
#     "slope_mean": 68.67503888481752,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4851",
#     "area_sqkm": 15.066000256500372,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 451.8882129725217,
#     "inital_state": "zero",
#     "lat": -70.16053794018356,
#     "lon": 46.224719874775055,
#     "slope_mean": 63.68985932553998,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4857",
#     "area_sqkm": 9.257401030496172,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 442.64189840833745,
#     "inital_state": "zero",
#     "lat": -70.20161748543245,
#     "lon": 46.24841766001805,
#     "slope_mean": 64.92795059013687,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4852",
#     "area_sqkm": 85.2155988884917,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 423.6692525032443,
#     "inital_state": "zero",
#     "lat": -70.14063344104244,
#     "lon": 46.30341167149405,
#     "slope_mean": 63.52029249746005,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4858",
#     "area_sqkm": 10.941299658001048,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 392.31134273027317,
#     "inital_state": "zero",
#     "lat": -70.05559557752032,
#     "lon": 46.36201121334253,
#     "slope_mean": 55.87750535200158,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4853",
#     "area_sqkm": 14.040449356498694,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 374.7809540459196,
#     "inital_state": "zero",
#     "lat": -70.06943776632218,
#     "lon": 46.388730492332456,
#     "slope_mean": 44.89605831185295,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4565",
#     "area_sqkm": 8.311950040504023,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 382.24019762776385,
#     "inital_state": "zero",
#     "lat": -70.08990759196914,
#     "lon": 46.42896036851996,
#     "slope_mean": 40.25214678981889,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4567",
#     "area_sqkm": 13.610700053999029,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 371.7183834186941,
#     "inital_state": "zero",
#     "lat": -70.01890405919819,
#     "lon": 46.49116852938128,
#     "slope_mean": 43.949713555817915,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4569",
#     "area_sqkm": 11.014650661499978,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 361.88274887180114,
#     "inital_state": "zero",
#     "lat": -69.9595162044169,
#     "lon": 46.50727905184208,
#     "slope_mean": 56.55915006747717,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4571",
#     "area_sqkm": 7.085249909998304,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 358.7973138931933,
#     "inital_state": "zero",
#     "lat": -69.88168022830361,
#     "lon": 46.46913793674883,
#     "slope_mean": 66.65204271704735,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4861",
#     "area_sqkm": 4.891049837999275,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 372.33971377199487,
#     "inital_state": "zero",
#     "lat": -69.88873217739462,
#     "lon": 46.49146975736759,
#     "slope_mean": 49.354089299547525,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4572",
#     "area_sqkm": 5.201549716500261,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 349.4128078462459,
#     "inital_state": "zero",
#     "lat": -69.86411829503666,
#     "lon": 46.48313152294592,
#     "slope_mean": 58.15154623863729,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4768",
#     "area_sqkm": 14.611499005502237,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 426.4732668875834,
#     "inital_state": "zero",
#     "lat": -69.85976643424131,
#     "lon": 46.4281446154141,
#     "slope_mean": 70.54899105849164,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-

#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4893",
#     "area_sqkm": 5.458048893001104,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 380.3796238260137,
#     "inital_state": "zero",
#     "lat": -69.71102672550784,
#     "lon": 46.63973933998672,
#     "slope_mean": 74.5965895107745,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4895",
#     "area_sqkm": 5.643899806503292,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 378.16221490378877,
#     "inital_state": "zero",
#     "lat": -69.7250260316828,
#     "lon": 46.63010959901782,
#     "slope_mean": 69.23287330085387,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4894",
#     "area_sqkm": 15.083100414001478,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 346.38715460501527,
#     "inital_state": "zero",
#     "lat": -69.71318389264847,
#     "lon": 46.6609952832636,
#     "slope_mean": 65.84565570324436,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   },
#   {
#     "catchment": "cat-4892",
#     "area_sqkm": 12.66345055800265,
#     "basin_id": "gages-01010000",
#     "basin_name": "",
#     "elev_mean": 347.1781260444996,
#     "inital_state": "zero",
#     "lat": -69.79092468062109,
#     "lon": 46.70216611896246,
#     "slope_mean": 54.01516800990739,
#     "timestep": "1 hour",
#     "train_cfg_file": "",
#     "verbose": "0"
#   }
# ]

# %% [markdown]
# ### CLI
#
# Now that we can return to the user all of the information / IPEs for a module, we can use the icefabric CLI to generate config files to disk for the user

# %%
Path("/tmp/lstm_output_test").mkdir(exist_ok=True, parents=True)

# Ensure the current working dir is where your `.pyiceberg.yaml` file is located
# !uv run icefabric params --gauge 01010000 --nwm-module lstm --domain conus_hf --catalog sql --output /tmp/lstm_output_test
# Out:
# Loading existing network graph from disk for: conus_hf
# Starting subset for gages-01010000
# Found origin flowpath: wb-4581
# Tracking 170 total upstream segments
# Subsetting network layer
# Subsetting flowpaths layer
# Subsetting nexus layer
# Subsetting divides layer
# Subsetting divide-attributes layer
# Creating a config file: 100%|██████████████████████████████████████████████████████████████████████████| 169/169 [00:00<00:00, 25429.14it/s]
# Config files created successfully in the following folder: /tmp/lstm_output_test

# %% [markdown]
# Now that these are created, let's view the contents

# %%
with zipfile.ZipFile("/tmp/lstm_output_test/configs.zip", "r") as f:
    print("Files in archive:")
    for file_info in f.filelist:
        print(f"  {file_info.filename} ({file_info.file_size} bytes)")
    f.extractall("/tmp/lstm_output_test/configs")
# Out:
# Files in archive:
#   cat-4564_bmi_config_lstm.txt (239 bytes)
#   cat-4568_bmi_config_lstm.txt (237 bytes)
#   cat-4575_bmi_config_lstm.txt (236 bytes)
#   cat-4581_bmi_config_lstm.txt (237 bytes)
#   cat-4758_bmi_config_lstm.txt (235 bytes)
#   cat-4761_bmi_config_lstm.txt (234 bytes)
#   cat-4820_bmi_config_lstm.txt (237 bytes)
#   cat-4859_bmi_config_lstm.txt (239 bytes)
#   cat-4862_bmi_config_lstm.txt (236 bytes)
#   cat-4865_bmi_config_lstm.txt (236 bytes)
#   cat-4866_bmi_config_lstm.txt (237 bytes)
#   cat-4870_bmi_config_lstm.txt (237 bytes)
#   cat-4874_bmi_config_lstm.txt (236 bytes)
#   cat-4566_bmi_config_lstm.txt (237 bytes)
#   cat-4570_bmi_config_lstm.txt (238 bytes)
#   cat-4573_bmi_config_lstm.txt (236 bytes)
#   cat-4574_bmi_config_lstm.txt (236 bytes)
#   cat-4578_bmi_config_lstm.txt (235 bytes)
#   cat-4579_bmi_config_lstm.txt (237 bytes)
#   cat-4580_bmi_config_lstm.txt (237 bytes)
#   cat-4749_bmi_config_lstm.txt (238 bytes)
#   cat-4755_bmi_config_lstm.txt (234 bytes)
#   cat-4764_bmi_config_lstm.txt (237 bytes)
#   cat-4766_bmi_config_lstm.txt (237 bytes)
#   cat-4769_bmi_config_lstm.txt (235 bytes)
#   cat-4771_bmi_config_lstm.txt (236 bytes)
#   cat-4773_bmi_config_lstm.txt (236 bytes)
#   cat-4776_bmi_config_lstm.txt (238 bytes)
#   cat-4780_bmi_config_lstm.txt (236 bytes)
#   cat-4784_bmi_config_lstm.txt (237 bytes)
#   cat-4788_bmi_config_lstm.txt (236 bytes)
#   cat-4789_bmi_config_lstm.txt (236 bytes)
#   cat-4798_bmi_config_lstm.txt (237 bytes)
#   cat-4801_bmi_config_lstm.txt (236 bytes)
#   cat-4807_bmi_config_lstm.txt (237 bytes)
#   cat-4813_bmi_config_lstm.txt (236 bytes)
#   cat-4822_bmi_config_lstm.txt (237 bytes)
#   cat-4828_bmi_config_lstm.txt (239 bytes)
#   cat-4830_bmi_config_lstm.txt (239 bytes)
#   cat-4834_bmi_config_lstm.txt (237 bytes)
#   cat-4837_bmi_config_lstm.txt (237 bytes)
#   cat-4841_bmi_config_lstm.txt (237 bytes)
#   cat-4844_bmi_config_lstm.txt (237 bytes)
#   cat-4847_bmi_config_lstm.txt (236 bytes)
#   cat-4850_bmi_config_lstm.txt (236 bytes)
#   cat-4863_bmi_config_lstm.txt (237 bytes)
#   cat-4868_bmi_config_lstm.txt (235 bytes)
#   cat-4872_bmi_config_lstm.txt (237 bytes)
#   cat-4889_bmi_config_lstm.txt (237 bytes)
#   cat-4890_bmi_config_lstm.txt (236 bytes)
#   cat-4748_bmi_config_lstm.txt (238 bytes)
#   cat-4750_bmi_config_lstm.txt (237 bytes)
#   cat-4751_bmi_config_lstm.txt (236 bytes)
#   cat-4754_bmi_config_lstm.txt (235 bytes)
#   cat-4752_bmi_config_lstm.txt (236 bytes)
#   cat-4753_bmi_config_lstm.txt (235 bytes)
#   cat-4896_bmi_config_lstm.txt (238 bytes)
#   cat-4869_bmi_config_lstm.txt (236 bytes)
#   cat-4878_bmi_config_lstm.txt (236 bytes)
#   cat-4876_bmi_config_lstm.txt (237 bytes)
#   cat-4877_bmi_config_lstm.txt (237 bytes)
#   cat-4871_bmi_config_lstm.txt (237 bytes)
#   cat-4864_bmi_config_lstm.txt (238 bytes)
#   cat-4873_bmi_config_lstm.txt (238 bytes)
#   cat-4875_bmi_config_lstm.txt (237 bytes)
#   cat-4867_bmi_config_lstm.txt (235 bytes)
#   cat-4879_bmi_config_lstm.txt (236 bytes)
#   cat-4880_bmi_config_lstm.txt (239 bytes)
#   cat-4767_bmi_config_lstm.txt (237 bytes)
#   cat-4762_bmi_config_lstm.txt (235 bytes)
#   cat-4765_bmi_config_lstm.txt (237 bytes)
#   cat-4763_bmi_config_lstm.txt (238 bytes)
#   cat-4848_bmi_config_lstm.txt (237 bytes)
#   cat-4846_bmi_config_lstm.txt (237 bytes)
#   cat-4839_bmi_config_lstm.txt (235 bytes)
#   cat-4842_bmi_config_lstm.txt (236 bytes)
#   cat-4840_bmi_config_lstm.txt (238 bytes)
#   cat-4843_bmi_config_lstm.txt (239 bytes)
#   cat-4835_bmi_config_lstm.txt (235 bytes)
#   cat-4836_bmi_config_lstm.txt (237 bytes)
#   cat-4818_bmi_config_lstm.txt (238 bytes)
#   cat-4772_bmi_config_lstm.txt (235 bytes)
#   cat-4814_bmi_config_lstm.txt (236 bytes)
#   cat-4815_bmi_config_lstm.txt (237 bytes)
#   cat-4774_bmi_config_lstm.txt (238 bytes)
#   cat-4775_bmi_config_lstm.txt (237 bytes)
#   cat-4816_bmi_config_lstm.txt (238 bytes)
#   cat-4817_bmi_config_lstm.txt (235 bytes)
#   cat-4823_bmi_config_lstm.txt (237 bytes)
#   cat-4824_bmi_config_lstm.txt (236 bytes)
#   cat-4819_bmi_config_lstm.txt (236 bytes)
#   cat-4821_bmi_config_lstm.txt (237 bytes)
#   cat-4777_bmi_config_lstm.txt (236 bytes)
#   cat-4778_bmi_config_lstm.txt (237 bytes)
#   cat-4810_bmi_config_lstm.txt (237 bytes)
#   cat-4812_bmi_config_lstm.txt (236 bytes)
#   cat-4811_bmi_config_lstm.txt (238 bytes)
#   cat-4779_bmi_config_lstm.txt (237 bytes)
#   cat-4825_bmi_config_lstm.txt (236 bytes)
#   cat-4827_bmi_config_lstm.txt (238 bytes)
#   cat-4826_bmi_config_lstm.txt (235 bytes)
#   cat-4809_bmi_config_lstm.txt (237 bytes)
#   cat-4808_bmi_config_lstm.txt (238 bytes)
#   cat-4781_bmi_config_lstm.txt (237 bytes)
#   cat-4832_bmi_config_lstm.txt (240 bytes)
#   cat-4833_bmi_config_lstm.txt (236 bytes)
#   cat-4829_bmi_config_lstm.txt (238 bytes)
#   cat-4831_bmi_config_lstm.txt (235 bytes)
#   cat-4782_bmi_config_lstm.txt (240 bytes)
#   cat-4783_bmi_config_lstm.txt (238 bytes)
#   cat-4785_bmi_config_lstm.txt (238 bytes)
#   cat-4838_bmi_config_lstm.txt (238 bytes)
#   cat-4786_bmi_config_lstm.txt (235 bytes)
#   cat-4796_bmi_config_lstm.txt (236 bytes)
#   cat-4797_bmi_config_lstm.txt (238 bytes)
#   cat-4799_bmi_config_lstm.txt (237 bytes)
#   cat-4804_bmi_config_lstm.txt (236 bytes)
#   cat-4802_bmi_config_lstm.txt (237 bytes)
#   cat-4805_bmi_config_lstm.txt (235 bytes)
#   cat-4803_bmi_config_lstm.txt (236 bytes)
#   cat-4800_bmi_config_lstm.txt (236 bytes)
#   cat-4791_bmi_config_lstm.txt (237 bytes)
#   cat-4792_bmi_config_lstm.txt (237 bytes)
#   cat-4793_bmi_config_lstm.txt (237 bytes)
#   cat-4794_bmi_config_lstm.txt (237 bytes)
#   cat-4806_bmi_config_lstm.txt (236 bytes)
#   cat-4795_bmi_config_lstm.txt (237 bytes)
#   cat-4787_bmi_config_lstm.txt (238 bytes)
#   cat-4845_bmi_config_lstm.txt (239 bytes)
#   cat-4790_bmi_config_lstm.txt (236 bytes)
#   cat-4860_bmi_config_lstm.txt (237 bytes)
#   cat-4562_bmi_config_lstm.txt (236 bytes)
#   cat-4563_bmi_config_lstm.txt (237 bytes)
#   cat-4849_bmi_config_lstm.txt (238 bytes)
#   cat-4855_bmi_config_lstm.txt (236 bytes)
#   cat-4854_bmi_config_lstm.txt (238 bytes)
#   cat-4856_bmi_config_lstm.txt (237 bytes)
#   cat-4851_bmi_config_lstm.txt (238 bytes)
#   cat-4857_bmi_config_lstm.txt (237 bytes)
#   cat-4852_bmi_config_lstm.txt (235 bytes)
#   cat-4858_bmi_config_lstm.txt (238 bytes)
#   cat-4853_bmi_config_lstm.txt (238 bytes)
#   cat-4565_bmi_config_lstm.txt (237 bytes)
#   cat-4567_bmi_config_lstm.txt (238 bytes)
#   cat-4569_bmi_config_lstm.txt (237 bytes)
#   cat-4571_bmi_config_lstm.txt (236 bytes)
#   cat-4861_bmi_config_lstm.txt (238 bytes)
#   cat-4572_bmi_config_lstm.txt (236 bytes)
#   cat-4768_bmi_config_lstm.txt (236 bytes)
#   cat-4770_bmi_config_lstm.txt (236 bytes)
#   cat-4576_bmi_config_lstm.txt (236 bytes)
#   cat-4881_bmi_config_lstm.txt (236 bytes)
#   cat-4577_bmi_config_lstm.txt (238 bytes)
#   cat-4882_bmi_config_lstm.txt (238 bytes)
#   cat-4883_bmi_config_lstm.txt (237 bytes)
#   cat-4760_bmi_config_lstm.txt (237 bytes)
#   cat-4759_bmi_config_lstm.txt (237 bytes)
#   cat-4756_bmi_config_lstm.txt (239 bytes)
#   cat-4757_bmi_config_lstm.txt (240 bytes)
#   cat-4884_bmi_config_lstm.txt (237 bytes)
#   cat-4885_bmi_config_lstm.txt (236 bytes)
#   cat-4886_bmi_config_lstm.txt (237 bytes)
#   cat-4888_bmi_config_lstm.txt (236 bytes)
#   cat-4887_bmi_config_lstm.txt (237 bytes)
#   cat-4891_bmi_config_lstm.txt (236 bytes)
#   cat-4893_bmi_config_lstm.txt (235 bytes)
#   cat-4895_bmi_config_lstm.txt (236 bytes)
#   cat-4894_bmi_config_lstm.txt (237 bytes)
#   cat-4892_bmi_config_lstm.txt (236 bytes)
#   metadata.json (110 bytes)

# %% [markdown]
# Let's view one of their contents

# %%
files = Path("/tmp/lstm_output_test/configs").glob("*")
first_file = list(files)[0]
content = first_file.read_text()
print(content)
# Out:
# area_sqkm: 5.192999833499175
# basin_id: gages-01010000
# basin_name:
# elev_mean: 340.5621527962976
# inital_state: zero
# lat: -69.78632341528159
# lon: 46.72490938929001
# slope_mean: 55.08073454429075
# timestep: 1 hour
# train_cfg_file:
# verbose: 0

# %% [markdown]
# We can also view the metadata.json file that was created. This will contain additional information about the query parameters used to make these configs

# %%
metadata = Path("/tmp/lstm_output_test/configs/metadata.json")
content = json.loads(metadata.read_text())

print(content)
# Out:
# {'gauge_id': '01010000', 'domain': 'conus_hf', 'version': '2025.7.1', 'module': 'lstm', 'catalog_type': 'sql'}

# %% [markdown]
# Through either the API, or CLI, any modeler can create a BMI Config file for SFT that is compatible with NextGen. Now, let's clean up the `/tmp/` dir

# %%
# !rm -rf /tmp/lstm_output_test
